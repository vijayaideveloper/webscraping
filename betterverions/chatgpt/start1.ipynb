# %%
import pandas as pd
import sqlite3
import requests
from bs4 import BeautifulSoup

URL = "https://www.scrapethissite.com/pages/simple/"

try:
    response = requests.get(URL, timeout=10)
    response.raise_for_status()
except requests.exceptions.RequestException as e:
    print("Request failed:", e)
    exit()

soup = BeautifulSoup(response.text, "html.parser")

countries = soup.select("div.country")
data = []

for country in countries:
    name = country.find("h3").text.strip()

    info = country.find("div", class_="country-info")
    capital = info.find("span", class_="country-capital").text.strip()
    population = int(info.find("span", class_="country-population").text.strip())
    area = float(info.find("span", class_="country-area").text.strip())

    print(f"{name} collected ✔")

    data.append({
        "Country": name,
        "Capital": capital,
        "Population": population,
        "Area": area
    })

df = pd.DataFrame(data)

df.to_csv("Country.csv", index=False)
df.to_excel("Country.xlsx", index=False)
df.to_json("Country.json", orient="records", indent=4)

conn = sqlite3.connect("country.db")
df.to_sql("countries_data", conn, if_exists="replace", index=False)
conn.close()

print("All files saved successfully ✅")
# Out:
# Andorra collected ✔
# United Arab Emirates collected ✔
# Afghanistan collected ✔
# Antigua and Barbuda collected ✔
# Anguilla collected ✔
# Albania collected ✔
# Armenia collected ✔
# Angola collected ✔
# Antarctica collected ✔
# Argentina collected ✔
# American Samoa collected ✔
# Austria collected ✔
# Australia collected ✔
# Aruba collected ✔
# Åland collected ✔
# Azerbaijan collected ✔
# Bosnia and Herzegovina collected ✔
# Barbados collected ✔
# Bangladesh collected ✔
# Belgium collected ✔
# Burkina Faso collected ✔
# Bulgaria collected ✔
# Bahrain collected ✔
# Burundi collected ✔
# Benin collected ✔
# Saint Barthélemy collected ✔
# Bermuda collected ✔
# Brunei collected ✔
# Bolivia collected ✔
# Bonaire collected ✔
# Brazil collected ✔
# Bahamas collected ✔
# Bhutan collected ✔
# Bouvet Island collected ✔
# Botswana collected ✔
# Belarus collected ✔
# Belize collected ✔
# Canada collected ✔
# Cocos [Keeling] Islands collected ✔
# Democratic Republic of the Congo collected ✔
# Central African Republic collected ✔
# Republic of the Congo collected ✔
# Switzerland collected ✔
# Ivory Coast collected ✔
# Cook Islands collected ✔
# Chile collected ✔
# Cameroon collected ✔
# China collected ✔
# Colombia collected ✔
# Costa Rica collected ✔
# Cuba collected ✔
# Cape Verde collected ✔
# Curacao collected ✔
# Christmas Island collected ✔
# Cyprus collected ✔
# Czech Republic collected ✔
# Germany collected ✔
# Djibouti collected ✔
# Denmark collected ✔
# Dominica collected ✔
# Dominican Republic collected ✔
# Algeria collected ✔
# Ecuador collected ✔
# Estonia collected ✔
# Egypt collected ✔
# Western Sahara collected ✔
# Eritrea collected ✔
# Spain collected ✔
# Ethiopia collected ✔
# Finland collected ✔
# Fiji collected ✔
# Falkland Islands collected ✔
# Micronesia collected ✔
# Faroe Islands collected ✔
# France collected ✔
# Gabon collected ✔
# United Kingdom collected ✔
# Grenada collected ✔
# Georgia collected ✔
# French Guiana collected ✔
# Guernsey collected ✔
# Ghana collected ✔
# Gibraltar collected ✔
# Greenland collected ✔
# Gambia collected ✔
# Guinea collected ✔
# Guadeloupe collected ✔
# Equatorial Guinea collected ✔
# Greece collected ✔
# South Georgia and the South Sandwich Islands collected ✔
# Guatemala collected ✔
# Guam collected ✔
# Guinea-Bissau collected ✔
# Guyana collected ✔
# Hong Kong collected ✔
# Heard Island and McDonald Islands collected ✔
# Honduras collected ✔
# Croatia collected ✔
# Haiti collected ✔
# Hungary collected ✔
# Indonesia collected ✔
# Ireland collected ✔
# Israel collected ✔
# Isle of Man collected ✔
# India collected ✔
# British Indian Ocean Territory collected ✔
# Iraq collected ✔
# Iran collected ✔
# Iceland collected ✔
# Italy collected ✔
# Jersey collected ✔
# Jamaica collected ✔
# Jordan collected ✔
# Japan collected ✔
# Kenya collected ✔
# Kyrgyzstan collected ✔
# Cambodia collected ✔
# Kiribati collected ✔
# Comoros collected ✔
# Saint Kitts and Nevis collected ✔
# North Korea collected ✔
# South Korea collected ✔
# Kuwait collected ✔
# Cayman Islands collected ✔
# Kazakhstan collected ✔
# Laos collected ✔
# Lebanon collected ✔
# Saint Lucia collected ✔
# Liechtenstein collected ✔
# Sri Lanka collected ✔
# Liberia collected ✔
# Lesotho collected ✔
# Lithuania collected ✔
# Luxembourg collected ✔
# Latvia collected ✔
# Libya collected ✔
# Morocco collected ✔
# Monaco collected ✔
# Moldova collected ✔
# Montenegro collected ✔
# Saint Martin collected ✔
# Madagascar collected ✔
# Marshall Islands collected ✔
# Macedonia collected ✔
# Mali collected ✔
# Myanmar [Burma] collected ✔
# Mongolia collected ✔
# Macao collected ✔
# Northern Mariana Islands collected ✔
# Martinique collected ✔
# Mauritania collected ✔
# Montserrat collected ✔
# Malta collected ✔
# Mauritius collected ✔
# Maldives collected ✔
# Malawi collected ✔
# Mexico collected ✔
# Malaysia collected ✔
# Mozambique collected ✔
# Namibia collected ✔
# New Caledonia collected ✔
# Niger collected ✔
# Norfolk Island collected ✔
# Nigeria collected ✔
# Nicaragua collected ✔
# Netherlands collected ✔
# Norway collected ✔
# Nepal collected ✔
# Nauru collected ✔
# Niue collected ✔
# New Zealand collected ✔
# Oman collected ✔
# Panama collected ✔
# Peru collected ✔
# French Polynesia collected ✔
# Papua New Guinea collected ✔
# Philippines collected ✔
# Pakistan collected ✔
# Poland collected ✔
# Saint Pierre and Miquelon collected ✔
# Pitcairn Islands collected ✔
# Puerto Rico collected ✔
# Palestine collected ✔
# Portugal collected ✔
# Palau collected ✔
# Paraguay collected ✔
# Qatar collected ✔
# Réunion collected ✔
# Romania collected ✔
# Serbia collected ✔
# Russia collected ✔
# Rwanda collected ✔
# Saudi Arabia collected ✔
# Solomon Islands collected ✔
# Seychelles collected ✔
# Sudan collected ✔
# Sweden collected ✔
# Singapore collected ✔
# Saint Helena collected ✔
# Slovenia collected ✔
# Svalbard and Jan Mayen collected ✔
# Slovakia collected ✔
# Sierra Leone collected ✔
# San Marino collected ✔
# Senegal collected ✔
# Somalia collected ✔
# Suriname collected ✔
# South Sudan collected ✔
# São Tomé and Príncipe collected ✔
# El Salvador collected ✔
# Sint Maarten collected ✔
# Syria collected ✔
# Swaziland collected ✔
# Turks and Caicos Islands collected ✔
# Chad collected ✔
# French Southern Territories collected ✔
# Togo collected ✔
# Thailand collected ✔
# Tajikistan collected ✔
# Tokelau collected ✔
# East Timor collected ✔
# Turkmenistan collected ✔
# Tunisia collected ✔
# Tonga collected ✔
# Turkey collected ✔
# Trinidad and Tobago collected ✔
# Tuvalu collected ✔
# Taiwan collected ✔
# Tanzania collected ✔
# Ukraine collected ✔
# Uganda collected ✔
# U.S. Minor Outlying Islands collected ✔
# United States collected ✔
# Uruguay collected ✔
# Uzbekistan collected ✔
# Vatican City collected ✔
# Saint Vincent and the Grenadines collected ✔
# Venezuela collected ✔
# British Virgin Islands collected ✔
# U.S. Virgin Islands collected ✔
# Vietnam collected ✔
# Vanuatu collected ✔
# Wallis and Futuna collected ✔
# Samoa collected ✔
# Kosovo collected ✔
# Yemen collected ✔
# Mayotte collected ✔
# South Africa collected ✔
# Zambia collected ✔
# Zimbabwe collected ✔
# All files saved successfully ✅
