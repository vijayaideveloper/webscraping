# %%
import pandas as pd

# %%
data = pd.read_csv('Moive_box_office_data.csv')

# %%
data.tail()
# Out:
#                 Movie Name   Box Office     Budget    Verdict  BoxOffice/Cores
# 144                    FIR     12 Crore   20 Crore       Flop               32
# 145                 Aaratu   17.8 Crore   18 Crore       Flop               32
# 146  Veerame Vaagai Soodum      9 Crore   20 Crore       Flop               32
# 147             Bangarraju  63.65 Crore   35 Crore        Hit               32
# 148                 Pushpa    352 Crore  180 Crore  Super Hit               32

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Movie Name  149 non-null    str
#  1   Box Office  149 non-null    str
#  2   Budget      149 non-null    str
#  3   Verdict     149 non-null    str
# dtypes: str(4)
# memory usage: 4.8 KB

# %%
data.describe()
# Out:
#            Movie Name Box Office   Budget Verdict
# count             149        149      149     149
# unique            149        138       54       9
# top     Thaai Kizhavi   12 Crore  8 Crore    Flop
# freq                1          3       11      52

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data['Box Office'] = data['Box Office'].str.replace(' Crore', '', regex=False)

# %%
data['Box Office'] = data['Box Office'].astype(float)

# %%
data['Box Office']
# Out:
# 0       69.00
# 1       32.00
# 2        0.20
# 3       16.00
# 4       86.30
#         ...
# 144     12.00
# 145     17.80
# 146      9.00
# 147     63.65
# 148    352.00
# Name: Box Office, Length: 149, dtype: float64

# %%
data['Budget'] = data['Budget'].str.replace(' Crore','',regex=False)

# %%
data['Budget'].astype(float)
# Out:
# 0       18.0
# 1        8.0
# 2        8.0
# 3       24.0
# 4      150.0
#        ...
# 144     20.0
# 145     18.0
# 146     20.0
# 147     35.0
# 148    180.0
# Name: Budget, Length: 149, dtype: float64

# %%
data.head()
# Out:
#                  Movie Name  Box Office Budget      Verdict
# 0             Thaai Kizhavi        69.0     18          Hit
# 1                 With Love        32.0      8          Hit
# 2                    Pookie         0.2      8         Flop
# 3  Manakantha ( Re Release)        16.0     24  Blockbuster
# 4                Parasakthi        86.3    150         Flop

# %%
data.to_csv('cleaned_data.csv', index=False)
