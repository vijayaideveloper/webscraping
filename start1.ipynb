# %%
# importing nessecery packages
from bs4 import BeautifulSoup
import pandas as pd
import requests
import time

# %%
data = []

# %%
for i in range(1,51):
    url = f"http://books.toscrape.com/catalogue/page-{i}.html"
    half_url = "http://books.toscrape.com/catalogue/"
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    books = soup.find("ol", class_="row").find_all("li")
    for book in books:
        link = book.find("div", class_="image_container").find("a")['href']
        full_url = half_url+link
        
        data.append({
            "Link":full_url
        })
    print(f"Page : {i} is completed !")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/urllib3/connection.py:204, in HTTPConnection._new_conn(self)
#     203 try:
# --> 204     sock = connection.create_connection(
#     205         (self._dns_host, self.port),
#     206         self.timeout,
#     207         source_address=self.source_address,
#     208         socket_options=self.socket_options,
#     209     )
#     210 except socket.gaierror as e:
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File /usr/lib/python3.13/socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/urllib3/connection.py:500, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     499     self.putheader(header, value)
# --> 500 self.endheaders()
#     502 # If we're given a body we start sending that in chunks.
#
# File /usr/lib/python3.13/http/client.py:1353, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1352     raise CannotSendHeader()
# -> 1353 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /usr/lib/python3.13/http/client.py:1113, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1112 del self._buffer[:]
# -> 1113 self.send(msg)
#    1115 if message_body is not None:
#    1116
#    1117     # create a consistent interface to message_body
#
# File /usr/lib/python3.13/http/client.py:1057, in HTTPConnection.send(self, data)
#    1056 if self.auto_open:
# -> 1057     self.connect()
#    1058 else:
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/urllib3/connection.py:331, in HTTPConnection.connect(self)
#     330 def connect(self) -> None:
# --> 331     self.sock = self._new_conn()
#     332     if self._tunnel_host:
#     333         # If we're tunneling it means we're connected to our proxy.
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/urllib3/connection.py:211, in HTTPConnection._new_conn(self)
#     210 except socket.gaierror as e:
# --> 211     raise NameResolutionError(self.host, self, e) from e
#     212 except SocketTimeout as e:
#
# NameResolutionError: HTTPConnection(host='books.toscrape.com', port=80): Failed to resolve 'books.toscrape.com' ([Errno -3] Temporary failure in name resolution)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/urllib3/util/retry.py:535, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     534     reason = error or ResponseError(cause)
# --> 535     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     537 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='books.toscrape.com', port=80): Max retries exceeded with url: /catalogue/page-1.html (Caused by NameResolutionError("HTTPConnection(host='books.toscrape.com', port=80): Failed to resolve 'books.toscrape.com' ([Errno -3] Temporary failure in name resolution)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[3], line 4
#       2 url = f"http://books.toscrape.com/catalogue/page-{i}.html"
#       3 half_url = "http://books.toscrape.com/catalogue/"
# ----> 4 response = requests.get(url)
#       5 soup = BeautifulSoup(response.text, "html.parser")
#       6 books = soup.find("ol", class_="row").find_all("li")
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/requests/adapters.py:677, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     673     if isinstance(e.reason, _SSLError):
#     674         # This branch is for urllib3 v1.22 and later.
#     675         raise SSLError(e, request=request)
# --> 677     raise ConnectionError(e, request=request)
#     679 except ClosedPoolError as e:
#     680     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='books.toscrape.com', port=80): Max retries exceeded with url: /catalogue/page-1.html (Caused by NameResolutionError("HTTPConnection(host='books.toscrape.com', port=80): Failed to resolve 'books.toscrape.com' ([Errno -3] Temporary failure in name resolution)"))

# %%
len(data)
# Out:
# 1000

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#                                                 Link
# 0  http://books.toscrape.com/catalogue/a-light-in...
# 1  http://books.toscrape.com/catalogue/tipping-th...
# 2  http://books.toscrape.com/catalogue/soumission...
# 3  http://books.toscrape.com/catalogue/sharp-obje...
# 4  http://books.toscrape.com/catalogue/sapiens-a-...

# %%
completed_data = []

# %%
# Title, Price, Stocks,Tax, UPC
for i,link in df.iterrows():
    url2 = link['Link']
    response2 = requests.get(url2)
    soup = BeautifulSoup(response2.text, "html.parser")
    name = soup.find("div", class_="product_main").find("h1").text
    price = soup.find("div", class_="product_main").find("h1").find_next_sibling("p").text
    stocks = soup.find("div", class_="product_main").find("p").find_next_sibling("p").text.strip()
    stock = stocks.split('(')[1]
    stock = stock.replace(")", "")
    table = soup.find('table', class_='table') # Finds the table
    rows = table.find_all('tr')
    tax = rows[4].find('td').text
    upc = soup.find("table", class_="table").find("td").text

    completed_data.append({
        "Title":name,
        "Price":price,
        "Stocks":stock,
        "Tax":tax,
        "UPC":upc
    })
    print(f"Scraped Book {i+1} : {name} is Collected !")
    time.sleep(1)
# Out:
# Scraped Book 1 : A Light in the Attic is Collected !
# Scraped Book 2 : Tipping the Velvet is Collected !
# Scraped Book 3 : Soumission is Collected !
# Scraped Book 4 : Sharp Objects is Collected !
# Scraped Book 5 : Sapiens: A Brief History of Humankind is Collected !
# Scraped Book 6 : The Requiem Red is Collected !
# Scraped Book 7 : The Dirty Little Secrets of Getting Your Dream Job is Collected !
# Scraped Book 8 : The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull is Collected !
# Scraped Book 9 : The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics is Collected !
# Scraped Book 10 : The Black Maria is Collected !
# Scraped Book 11 : Starving Hearts (Triangular Trade Trilogy, #1) is Collected !
# Scraped Book 12 : Shakespeare's Sonnets is Collected !
# Scraped Book 13 : Set Me Free is Collected !
# Scraped Book 14 : Scott Pilgrim's Precious Little Life (Scott Pilgrim #1) is Collected !
# Scraped Book 15 : Rip it Up and Start Again is Collected !
# Scraped Book 16 : Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991 is Collected !
# Scraped Book 17 : Olio is Collected !
# Scraped Book 18 : Mesaerion: The Best Science Fiction Stories 1800-1849 is Collected !
# Scraped Book 19 : Libertarianism for Beginners is Collected !
# Scraped Book 20 : It's Only the Himalayas is Collected !
# Scraped Book 21 : In Her Wake is Collected !
# Scraped Book 22 : How Music Works is Collected !
# Scraped Book 23 : Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More is Collected !
# Scraped Book 24 : Chase Me (Paris Nights #2) is Collected !
# Scraped Book 25 : Black Dust is Collected !
# Scraped Book 26 : Birdsong: A Story in Pictures is Collected !
# Scraped Book 27 : America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana is Collected !
# Scraped Book 28 : Aladdin and His Wonderful Lamp is Collected !
# Scraped Book 29 : Worlds Elsewhere: Journeys Around Shakespeareâs Globe is Collected !
# Scraped Book 30 : Wall and Piece is Collected !
# Scraped Book 31 : The Four Agreements: A Practical Guide to Personal Freedom is Collected !
# Scraped Book 32 : The Five Love Languages: How to Express Heartfelt Commitment to Your Mate is Collected !
# Scraped Book 33 : The Elephant Tree is Collected !
# Scraped Book 34 : The Bear and the Piano is Collected !
# Scraped Book 35 : Sophie's World is Collected !
# Scraped Book 36 : Penny Maybe is Collected !
# Scraped Book 37 : Maude (1883-1993):She Grew Up with the country is Collected !
# Scraped Book 38 : In a Dark, Dark Wood is Collected !
# Scraped Book 39 : Behind Closed Doors is Collected !
# Scraped Book 40 : You can't bury them all: Poems is Collected !
# Scraped Book 41 : Slow States of Collapse: Poems is Collected !
# Scraped Book 42 : Reasons to Stay Alive is Collected !
# Scraped Book 43 : Private Paris (Private #10) is Collected !
# Scraped Book 44 : #HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe. is Collected !
# Scraped Book 201 : Dark Notes is Collected !
# Scraped Book 202 : Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead is Collected !
# Scraped Book 203 : Close to You is Collected !
# Scraped Book 204 : Chasing Heaven: What Dying Taught Me About Living is Collected !
# Scraped Book 205 : Big Magic: Creative Living Beyond Fear is Collected !
# Scraped Book 206 : Becoming Wise: An Inquiry into the Mystery and Art of Living is Collected !
# Scraped Book 207 : Beauty Restored (Riley Family Legacy Novellas #3) is Collected !
# Scraped Book 208 : Batman: The Long Halloween (Batman) is Collected !
# Scraped Book 209 : Batman: The Dark Knight Returns (Batman) is Collected !
# Scraped Book 210 : Ayumi's Violin is Collected !
# Scraped Book 211 : Anonymous is Collected !
# Scraped Book 212 : Amy Meets the Saints and Sages is Collected !
# Scraped Book 213 : Amid the Chaos is Collected !
# Scraped Book 214 : Amatus is Collected !
# Scraped Book 215 : Agnostic: A Spirited Manifesto is Collected !
# Scraped Book 216 : Zealot: The Life and Times of Jesus of Nazareth is Collected !
# Scraped Book 217 : You (You #1) is Collected !
# Scraped Book 218 : Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1) is Collected !
# Scraped Book 219 : Wild Swans is Collected !
# Scraped Book 220 : Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond is Collected !
# Scraped Book 221 : Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity is Collected !
# Scraped Book 222 : What's It Like in Space?: Stories from Astronauts Who've Been There is Collected !
# Scraped Book 223 : We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1) is Collected !
# Scraped Book 224 : Walt Disney's Alice in Wonderland is Collected !
# Scraped Book 225 : V for Vendetta (V for Vendetta Complete) is Collected !
# Scraped Book 226 : Until Friday Night (The Field Party #1) is Collected !
# Scraped Book 227 : Unbroken: A World War II Story of Survival, Resilience, and Redemption is Collected !
# Scraped Book 228 : Twenty Yawns is Collected !
# Scraped Book 229 : Through the Woods is Collected !
# Scraped Book 230 : This Is Where It Ends is Collected !
# Scraped Book 231 : The Year of Magical Thinking is Collected !
# Scraped Book 232 : The Wright Brothers is Collected !
# Scraped Book 233 : The White Queen (The Cousins' War #1) is Collected !
# Scraped Book 234 : The Wedding Pact (The O'Malleys #2) is Collected !
# Scraped Book 235 : The Time Keeper is Collected !
# Scraped Book 236 : The Testament of Mary is Collected !
# Scraped Book 237 : The Star-Touched Queen is Collected !
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 4
#       2 for i,link in df.iterrows():
#       3     url2 = link['Link']
# ----> 4     response2 = requests.get(url2)
#       5     soup = BeautifulSoup(response2.text, "html.parser")
#       6     name = soup.find("div", class_="product_main").find("h1").text
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Documents/Free Lancing/WebScraping/.venv/lib/python3.13/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File /usr/lib/python3.13/http/client.py:1450, in HTTPConnection.getresponse(self)
#    1448 try:
#    1449     try:
# -> 1450         response.begin()
#    1451     except ConnectionError:
#    1452         self.close()
#
# File /usr/lib/python3.13/http/client.py:336, in HTTPResponse.begin(self)
#     334 # read until we get a non-100 response
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#     338         break
#
# File /usr/lib/python3.13/http/client.py:297, in HTTPResponse._read_status(self)
#     296 def _read_status(self):
# --> 297     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     298     if len(line) > _MAXLINE:
#     299         raise LineTooLong("status line")
#
# File /usr/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# KeyboardInterrupt:
